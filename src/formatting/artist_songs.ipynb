# %%
import numpy as np
import pandas as pd

# %%
FILE_NAME = "../../data/artist_streams.csv"
SAVE_NAME = "../../data/artist_songs.csv"

# %%
print("Reading data...")
data = pd.read_csv(FILE_NAME)
print(f"Data shape: {raw_data.shape[0]} lines, {raw_data.shape[1]} columns")
# Out:
# Reading data...
# Data shape: 2242117 lines, 8 columns

# %%
data
# Out:
#                                           user_id          ts     sng_id  \
# 0        53a2a460127df49eef5976193c14728c695c3463  1471344689  121710324
# 1        d81f8a1d9fd30af3c189fbe99c26fd6d4db11375  1471364400  121710324
# 2        b26ce863e9161cc7e36cdf254927457cc5ceb55b  1471320765  121710324
# 3        206929899c1bfc3c49174d20824ab1dc77758567  1471355821  121710324
# 4        111f74340b5ef733f7dc99dc5494de3da4dbeea7  1471336531  121710324
# ...                                           ...         ...        ...
# 2242112  bb2a3a806a8d9ae05bc63fa2182a3fb645530a49  1471505913  117303310
# 2242113  92ff662b58d3bd81e5cdc06a6438ad4bf490d938  1471983156    9900601
# 2242114  92ff662b58d3bd81e5cdc06a6438ad4bf490d938  1471982447    9900591
# 2242115  92ff662b58d3bd81e5cdc06a6438ad4bf490d938  1471982430    9900589
# 2242116  92ff662b58d3bd81e5cdc06a6438ad4bf490d938  1471984162   17669990
#
#          album_id  listening_time listen_type         origin   art_id
# ...

# %%
data[["sng_id", "art_id"]].drop_duplicates().sort_values("art_id").to_csv(SAVE_NAME, index=False)
